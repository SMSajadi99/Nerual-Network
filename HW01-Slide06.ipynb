# %% [markdown]
# <a href="https://colab.research.google.com/github/SMSajadi99/Nerual-Network/blob/main/HW01-Slide06.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

def gaussian(x, mean, variance):
    return 1 / np.sqrt(2 * np.pi * variance) * np.exp(-(x - mean)**2 / (2 * variance))

# Input parameters
mean = float(input("Enter the mean: "))
variance = float(input("Enter the variance: "))
# num_points = int(input("Enter the number of points: "))
num_points = 50

# Generate random x values within a specified range
x_values = np.random.uniform(mean - 3 * np.sqrt(variance), mean + 3 * np.sqrt(variance), num_points)

# Evaluate the Gaussian function for each x value
y_values = gaussian(x_values, mean, variance)

# Plot the Gaussian distribution
x_range = np.linspace(mean - 3 * np.sqrt(variance), mean + 3 * np.sqrt(variance), 1000)
plt.plot(x_range, gaussian(x_range, mean, variance), label='Gaussian Distribution')
plt.scatter(x_values, y_values, color='red', label='Randomly chosen points')

plt.title('Gaussian Distribution')
plt.xlabel('X')
plt.ylabel('Probability Density')
plt.legend()
plt.show()

# Display the lists
print("X values:", x_values)
print("Corresponding Y values:", y_values)
x_values_model_1 = x_values
y_values_model_1 = y_values
# Out:
# Enter the mean: 0
# Enter the variance: 1
# X values: [-1.77148495 -2.06795098 -0.09813713  2.79933586 -2.97558031  0.01466564
#  -2.53542495 -2.05819391  2.48468121  0.45223133 -1.35018221  1.23734347
#  -1.34420841 -2.9199817  -1.98167548  0.62549068  0.60238977 -2.98192273
#  -0.91583308 -1.46152269  1.601155    2.67916428  0.161981    0.24161871
#   2.39264896  0.53173318 -2.01587773 -1.4005188   1.98745183 -1.65015047
#  -1.55712779  2.90314615  0.17824376 -0.84031737  1.81447422  1.59095976
#  -2.15788001  2.07605227  2.78154667  0.47843247  1.18918385  2.23652374
#  -1.77960446  1.91073156  1.77780843  2.30441966  2.05503477 -0.65778036
#   1.83152846 -2.34617064]
# Corresponding Y values: [0.08307446 0.04702156 0.39702581 0.00793018 0.00476729 0.39889938
#  0.01603264 0.04797767 0.01821046 0.36016424 0.16034388 0.18554683
#  0.16163951 0.00561628 0.05599699 0.32806031 0.3327462  0.00467807
#  0.2622876  0.13711123 0.11071597 0.01102159 0.39374277 0.38746555
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

def gaussian(x, mean, variance):
    return 1 / np.sqrt(2 * np.pi * variance) * np.exp(-(x - mean)**2 / (2 * variance))

# Input parameters
mean = float(input("Enter the mean: "))
variance = float(input("Enter the variance: "))
# num_points = int(input("Enter the number of points: "))
num_points = 50

# Generate random x values within a specified range
x_values = np.random.uniform(mean - 3 * np.sqrt(variance), mean + 3 * np.sqrt(variance), num_points)

# Evaluate the Gaussian function for each x value
y_values = gaussian(x_values, mean, variance)

# Plot the Gaussian distribution
x_range = np.linspace(mean - 3 * np.sqrt(variance), mean + 3 * np.sqrt(variance), 1000)
plt.plot(x_range, gaussian(x_range, mean, variance), label='Gaussian Distribution')
plt.scatter(x_values, y_values, color='red', label='Randomly chosen points')

plt.title('Gaussian Distribution')
plt.xlabel('X')
plt.ylabel('Probability Density')
plt.legend()
plt.show()

# Display the lists
print("X values:", x_values)
print("Corresponding Y values:", y_values)
x_values_model_2 = x_values
y_values_model_2 = y_values
# Out:
# Enter the mean: 2
# Enter the variance: 1
# X values: [ 3.86371836  2.77055078  1.35151478 -0.87237912  4.84077153  2.98110031
#   0.15707396 -0.19104721  2.16793639  3.12932945  4.61109267  4.77613242
#   3.25208899  4.53952397  4.51400823  2.68452251  4.02670732  2.45767307
#   2.42666065  4.09939501  3.74771233  2.73626058  1.24808324 -0.85866789
#   2.44248308  0.91737502 -0.92656997  0.8373188   2.88229874  2.03307462
#   1.92101267  1.62961471  3.50486034  0.69997207  0.66118035  4.44416766
#   1.20575776  0.82917187  1.0608105   0.42328661  4.0244258   2.00317168
#   1.18618805  2.42084055  0.70425352  4.66091181  2.17941911  1.56969233
#   0.20739223  2.9741228 ]
# Corresponding Y values: [0.07025235 0.29646895 0.32329015 0.00644649 0.00705563 0.24654335
#  0.07301235 0.03617878 0.39335615 0.21084521 0.01319601 0.0084601
#  0.18217237 0.01586675 0.01692341 0.31561756 0.05116448 0.35927368
#  0.36423421 0.0440395  0.08662319 0.30422785 0.30070429 0.00670481
# ...

# %%
import random

# Get 10 random indices
random_indices_10 = random.sample(range(50), 10)

# Get 20 random indices
random_indices_20 = random.sample(range(50), 20)

# Get 30 random indices
random_indices_30 = random.sample(range(50), 30)

# Create training and testing lists for 10 random indices for model_1
X_training_list_10_model_1 = [x_values_model_1[i] for i in random_indices_10]
Y_training_list_10_model_1 = [y_values_model_1[i] for i in random_indices_10]

X_testing_list_10_model_1 = [x_values_model_1[i] for i in range(50) if i not in random_indices_10]
Y_testing_list_10_model_1 = [y_values_model_1[i] for i in range(50) if i not in random_indices_10]

# Create training and testing lists for 20 random indices for model_1
X_training_list_20_model_1 = [x_values_model_1[i] for i in random_indices_20]
Y_training_list_20_model_1 = [y_values_model_1[i] for i in random_indices_20]

X_testing_list_20_model_1 = [x_values_model_1[i] for i in range(50) if i not in random_indices_20]
Y_testing_list_20_model_1 = [y_values_model_1[i] for i in range(50) if i not in random_indices_20]

# Create training and testing lists for 30 random indices for model_1
X_training_list_30_model_1 = [x_values_model_1[i] for i in random_indices_30]
Y_training_list_30_model_1 = [y_values_model_1[i] for i in random_indices_30]

X_testing_list_30_model_1 = [x_values_model_1[i] for i in range(50) if i not in random_indices_30]
Y_testing_list_30_model_1 = [y_values_model_1[i] for i in range(50) if i not in random_indices_30]

# Create training and testing lists for 10 random indices for model_2
X_training_list_10_model_2 = [x_values_model_2[i] for i in random_indices_10]
Y_training_list_10_model_2 = [y_values_model_2[i] for i in random_indices_10]

X_testing_list_10_model_2 = [x_values_model_2[i] for i in range(50) if i not in random_indices_10]
Y_testing_list_10_model_2 = [y_values_model_2[i] for i in range(50) if i not in random_indices_10]

# Create training and testing lists for 20 random indices for model_2
X_training_list_20_model_2 = [x_values_model_2[i] for i in random_indices_20]
Y_training_list_20_model_2 = [y_values_model_2[i] for i in random_indices_20]

X_testing_list_20_model_2 = [x_values_model_2[i] for i in range(50) if i not in random_indices_20]
Y_testing_list_20_model_2 = [y_values_model_2[i] for i in range(50) if i not in random_indices_20]

# Create training and testing lists for 30 random indices for model_2
X_training_list_30_model_2 = [x_values_model_2[i] for i in random_indices_30]
Y_training_list_30_model_2 = [y_values_model_2[i] for i in random_indices_30]

X_testing_list_30_model_2 = [x_values_model_2[i] for i in range(50) if i not in random_indices_30]
Y_testing_list_30_model_2 = [y_values_model_2[i] for i in range(50) if i not in random_indices_30]

# Print sample of the results
print("Training List:", X_training_list_10_model_1)
print(len(X_training_list_10_model_1))
print("Testing List:", X_testing_list_10_model_1)
print(len(X_testing_list_10_model_1))
# Out:
# Training List: [2.679164280966771, -2.0679509789735926, 2.2365237424085533, 1.8315284629168165, -2.1578800087399683, 2.903146153319632, -0.9158330814088949, 1.1891838532404524, 0.6254906819776922, 1.2373434700140962]
# 10
# ...

# %% [markdown]
# # Model With 10 numbers of Training

# %%
import tensorflow as tf
import numpy as np
import random
import time

# Set a seed for reproducibility
tf.random.set_seed(42)
np.random.seed(42)
random.seed(42)

# Define your training and testing data
X_training_model_1 = np.array([x_values_model_1[i] for i in random_indices_10])
X_training_model_2 = np.array([x_values_model_2[i] for i in random_indices_10])

X_testing_model_1 = np.array([x_values_model_1[i] for i in range(50) if i not in random_indices_10])
X_testing_model_2 = np.array([x_values_model_2[i] for i in range(50) if i not in random_indices_10])

Y_training_model_1 = np.array([y_values_model_1[i] for i in random_indices_10])
Y_training_model_2 = np.array([y_values_model_2[i] for i in random_indices_10])

Y_testing_model_1 = np.array([y_values_model_1[i] for i in range(50) if i not in random_indices_10])
Y_testing_model_2 = np.array([y_values_model_2[i] for i in range(50) if i not in random_indices_10])

# Define the model
model = tf.keras.Sequential([
    tf.keras.layers.Dense(2, input_shape=(2,), activation='sigmoid'),  # 2 inputs, 2 outputs
])

# Compile the model
model.compile(optimizer='sgd', loss='mean_squared_error')

# Measure training time
start_time = time.time()

# Train the model
model.fit(np.column_stack((X_training_model_1, X_training_model_2)), np.column_stack((Y_training_model_1, Y_training_model_2)), epochs=10000)

training_time = time.time() - start_time

# Print the generated weights
weights = model.get_weights()
print("Generated Weights:")
for i, w in enumerate(weights):
    print(f"Layer {i + 1} weights shape: {w.shape}")
    print(w)

# Evaluate on the test set
predictions = model.predict(np.column_stack((X_testing_model_1, X_testing_model_2)))

# Calculate mean average precision (mAP) manually
mAP = np.mean(np.abs(Y_testing_model_1 - predictions[:, 0]) + np.abs(Y_testing_model_2 - predictions[:, 1]))

print("Training Time:", training_time, "seconds")
print("mAP:", mAP)
# Out:
# Streaming output truncated to the last 5000 lines.
# Epoch 7504/10000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0198
# Epoch 7505/10000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0198
# Epoch 7506/10000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0198
# Epoch 7507/10000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0198
# Epoch 7508/10000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0198
# Epoch 7509/10000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0198
# Epoch 7510/10000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0198
# Epoch 7511/10000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0198
# Epoch 7512/10000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0198
# Epoch 7513/10000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0198
# Epoch 7514/10000
# ...

# %%
import tensorflow as tf
import numpy as np
import random
import time

# Set a seed for reproducibility
tf.random.set_seed(42)
np.random.seed(42)
random.seed(42)

# Define your training and testing data
X_training_model_1 = np.array([x_values_model_1[i] for i in random_indices_10])
X_training_model_2 = np.array([x_values_model_2[i] for i in random_indices_10])

X_testing_model_1 = np.array([x_values_model_1[i] for i in range(50) if i not in random_indices_10])
X_testing_model_2 = np.array([x_values_model_2[i] for i in range(50) if i not in random_indices_10])

Y_training_model_1 = np.array([y_values_model_1[i] for i in random_indices_10])
Y_training_model_2 = np.array([y_values_model_2[i] for i in random_indices_10])

Y_testing_model_1 = np.array([y_values_model_1[i] for i in range(50) if i not in random_indices_10])
Y_testing_model_2 = np.array([y_values_model_2[i] for i in range(50) if i not in random_indices_10])

# Define the model with a lower learning rate
model = tf.keras.Sequential([
    tf.keras.layers.Dense(2, input_shape=(2,), activation='sigmoid'),  # 2 inputs, 2 outputs
])

# Compile the model with a lower learning rate
model.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=0.01), loss='mean_squared_error')

# Measure training time
start_time = time.time()

# Train the model
model.fit(np.column_stack((X_training_model_1, X_training_model_2)), np.column_stack((Y_training_model_1, Y_training_model_2)), epochs=1000)

training_time = time.time() - start_time

# Print the generated weights
weights = model.get_weights()
print("Generated Weights:")
for i, w in enumerate(weights):
    print(f"Layer {i + 1} weights shape: {w.shape}")
    print(w)

# Evaluate on the test set
predictions = model.predict(np.column_stack((X_testing_model_1, X_testing_model_2)))

# Calculate mean average precision (mAP) manually
mAP = np.mean(np.abs(Y_testing_model_1 - predictions[:, 0]) + np.abs(Y_testing_model_2 - predictions[:, 1]))

print("Training Time:", training_time, "seconds")
print("mAP:", mAP)

# %% [markdown]
# # Model With 20 numbers of Training

# %%
import tensorflow as tf
import numpy as np
import random
import time

# Set a seed for reproducibility
tf.random.set_seed(42)
np.random.seed(42)
random.seed(42)

# Define your training and testing data
X_training_model_1 = np.array([x_values_model_1[i] for i in random_indices_20])
X_training_model_2 = np.array([x_values_model_2[i] for i in random_indices_20])

X_testing_model_1 = np.array([x_values_model_1[i] for i in range(50) if i not in random_indices_20])
X_testing_model_2 = np.array([x_values_model_2[i] for i in range(50) if i not in random_indices_20])

Y_training_model_1 = np.array([y_values_model_1[i] for i in random_indices_20])
Y_training_model_2 = np.array([y_values_model_2[i] for i in random_indices_20])

Y_testing_model_1 = np.array([y_values_model_1[i] for i in range(50) if i not in random_indices_20])
Y_testing_model_2 = np.array([y_values_model_2[i] for i in range(50) if i not in random_indices_20])

# Define the model
model = tf.keras.Sequential([
    tf.keras.layers.Dense(2, input_shape=(2,), activation='sigmoid'),  # 2 inputs, 2 outputs
])

# Compile the model
model.compile(optimizer='sgd', loss='mean_squared_error')

# Measure training time
start_time = time.time()

# Train the model
model.fit(np.column_stack((X_training_model_1, X_training_model_2)), np.column_stack((Y_training_model_1, Y_training_model_2)), epochs=10000)

training_time = time.time() - start_time

# Print the generated weights
weights = model.get_weights()
print("Generated Weights:")
for i, w in enumerate(weights):
    print(f"Layer {i + 1} weights shape: {w.shape}")
    print(w)

# Evaluate on the test set
predictions = model.predict(np.column_stack((X_testing_model_1, X_testing_model_2)))

# Calculate mean average precision (mAP) manually
mAP = np.mean(np.abs(Y_testing_model_1 - predictions[:, 0]) + np.abs(Y_testing_model_2 - predictions[:, 1]))

print("Training Time:", training_time, "seconds")
print("mAP:", mAP)
# Out:
# Streaming output truncated to the last 5000 lines.
# Epoch 7504/10000
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0186
# Epoch 7505/10000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0186
# Epoch 7506/10000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0186
# Epoch 7507/10000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0186
# Epoch 7508/10000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0186
# Epoch 7509/10000
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0186
# Epoch 7510/10000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0186
# Epoch 7511/10000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0186
# Epoch 7512/10000
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0186
# Epoch 7513/10000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0186
# Epoch 7514/10000
# ...

# %%
import tensorflow as tf
import numpy as np
import random
import time

# Set a seed for reproducibility
tf.random.set_seed(42)
np.random.seed(42)
random.seed(42)

# Define your training and testing data
X_training_model_1 = np.array([x_values_model_1[i] for i in random_indices_20])
X_training_model_2 = np.array([x_values_model_2[i] for i in random_indices_20])

X_testing_model_1 = np.array([x_values_model_1[i] for i in range(50) if i not in random_indices_20])
X_testing_model_2 = np.array([x_values_model_2[i] for i in range(50) if i not in random_indices_20])

Y_training_model_1 = np.array([y_values_model_1[i] for i in random_indices_20])
Y_training_model_2 = np.array([y_values_model_2[i] for i in random_indices_20])

Y_testing_model_1 = np.array([y_values_model_1[i] for i in range(50) if i not in random_indices_20])
Y_testing_model_2 = np.array([y_values_model_2[i] for i in range(50) if i not in random_indices_20])

# Define the model with a lower learning rate
model = tf.keras.Sequential([
    tf.keras.layers.Dense(2, input_shape=(2,), activation='sigmoid'),  # 2 inputs, 2 outputs
])

# Compile the model with a lower learning rate
model.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=0.01), loss='mean_squared_error')

# Measure training time
start_time = time.time()

# Train the model
model.fit(np.column_stack((X_training_model_1, X_training_model_2)), np.column_stack((Y_training_model_1, Y_training_model_2)), epochs=1000)

training_time = time.time() - start_time

# Print the generated weights
weights = model.get_weights()
print("Generated Weights:")
for i, w in enumerate(weights):
    print(f"Layer {i + 1} weights shape: {w.shape}")
    print(w)

# Evaluate on the test set
predictions = model.predict(np.column_stack((X_testing_model_1, X_testing_model_2)))

# Calculate mean average precision (mAP) manually
mAP = np.mean(np.abs(Y_testing_model_1 - predictions[:, 0]) + np.abs(Y_testing_model_2 - predictions[:, 1]))

print("Training Time:", training_time, "seconds")
print("mAP:", mAP)

# %% [markdown]
# # Model With 30 numbers of Training

# %%
import tensorflow as tf
import numpy as np
import random
import time

# Set a seed for reproducibility
tf.random.set_seed(42)
np.random.seed(42)
random.seed(42)

# Define your training and testing data
X_training_model_1 = np.array([x_values_model_1[i] for i in random_indices_30])
X_training_model_2 = np.array([x_values_model_2[i] for i in random_indices_30])

X_testing_model_1 = np.array([x_values_model_1[i] for i in range(50) if i not in random_indices_30])
X_testing_model_2 = np.array([x_values_model_2[i] for i in range(50) if i not in random_indices_30])

Y_training_model_1 = np.array([y_values_model_1[i] for i in random_indices_30])
Y_training_model_2 = np.array([y_values_model_2[i] for i in random_indices_30])

Y_testing_model_1 = np.array([y_values_model_1[i] for i in range(50) if i not in random_indices_30])
Y_testing_model_2 = np.array([y_values_model_2[i] for i in range(50) if i not in random_indices_30])

# Define the model
model = tf.keras.Sequential([
    tf.keras.layers.Dense(2, input_shape=(2,), activation='sigmoid'),  # 2 inputs, 2 outputs
])

# Compile the model
model.compile(optimizer='sgd', loss='mean_squared_error')

# Measure training time
start_time = time.time()

# Train the model
model.fit(np.column_stack((X_training_model_1, X_training_model_2)), np.column_stack((Y_training_model_1, Y_training_model_2)), epochs=10000)

training_time = time.time() - start_time

# Print the generated weights
weights = model.get_weights()
print("Generated Weights:")
for i, w in enumerate(weights):
    print(f"Layer {i + 1} weights shape: {w.shape}")
    print(w)

# Evaluate on the test set
predictions = model.predict(np.column_stack((X_testing_model_1, X_testing_model_2)))

# Calculate mean average precision (mAP) manually
mAP = np.mean(np.abs(Y_testing_model_1 - predictions[:, 0]) + np.abs(Y_testing_model_2 - predictions[:, 1]))

print("Training Time:", training_time, "seconds")
print("mAP:", mAP)
# Out:
# Streaming output truncated to the last 5000 lines.
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0206
# Epoch 7506/10000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0206
# Epoch 7507/10000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0206
# Epoch 7508/10000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0206
# Epoch 7509/10000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0206
# Epoch 7510/10000
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0206
# Epoch 7511/10000
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0206
# Epoch 7512/10000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0206
# Epoch 7513/10000
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0206
# Epoch 7514/10000
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0206
# Epoch 7515/10000
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0206
# ...

# %%
import tensorflow as tf
import numpy as np
import random
import time

# Set a seed for reproducibility
tf.random.set_seed(42)
np.random.seed(42)
random.seed(42)

# Define your training and testing data
X_training_model_1 = np.array([x_values_model_1[i] for i in random_indices_30])
X_training_model_2 = np.array([x_values_model_2[i] for i in random_indices_30])

X_testing_model_1 = np.array([x_values_model_1[i] for i in range(50) if i not in random_indices_30])
X_testing_model_2 = np.array([x_values_model_2[i] for i in range(50) if i not in random_indices_30])

Y_training_model_1 = np.array([y_values_model_1[i] for i in random_indices_30])
Y_training_model_2 = np.array([y_values_model_2[i] for i in random_indices_30])

Y_testing_model_1 = np.array([y_values_model_1[i] for i in range(50) if i not in random_indices_30])
Y_testing_model_2 = np.array([y_values_model_2[i] for i in range(50) if i not in random_indices_30])

# Define the model with a lower learning rate
model = tf.keras.Sequential([
    tf.keras.layers.Dense(2, input_shape=(2,), activation='sigmoid'),  # 2 inputs, 2 outputs
])

# Compile the model with a lower learning rate
model.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=0.01), loss='mean_squared_error')

# Measure training time
start_time = time.time()

# Train the model
model.fit(np.column_stack((X_training_model_1, X_training_model_2)), np.column_stack((Y_training_model_1, Y_training_model_2)), epochs=10000)

training_time = time.time() - start_time

# Print the generated weights
weights = model.get_weights()
print("Generated Weights:")
for i, w in enumerate(weights):
    print(f"Layer {i + 1} weights shape: {w.shape}")
    print(w)

# Evaluate on the test set
predictions = model.predict(np.column_stack((X_testing_model_1, X_testing_model_2)))

# Calculate mean average precision (mAP) manually
mAP = np.mean(np.abs(Y_testing_model_1 - predictions[:, 0]) + np.abs(Y_testing_model_2 - predictions[:, 1]))

print("Training Time:", training_time, "seconds")
print("mAP:", mAP)
# Out:
# Streaming output truncated to the last 5000 lines.
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0206
# Epoch 7506/10000
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0206
# Epoch 7507/10000
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0206
# Epoch 7508/10000
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0206
# Epoch 7509/10000
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0206
# Epoch 7510/10000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0206
# Epoch 7511/10000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0206
# Epoch 7512/10000
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0206
# Epoch 7513/10000
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0206
# Epoch 7514/10000
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0206
# Epoch 7515/10000
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0206
# ...
